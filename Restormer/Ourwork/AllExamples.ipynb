# %%
from datasets import load_dataset

# Pass token directly to load_dataset
ds = load_dataset(
    "masterda/SloMoBlur", 
    split="train[:10000]",
    token=""  # Replace with your actual token
)

# %%
import os
from huggingface_hub import HfApi, hf_hub_download

def download_dataset():
    # Repository information
    repo_id = "masterda/SloMoBlur"
    repo_type = "dataset"
    
    # Output directory
    output_dir = "./Dataset/SloMoBlur"
    
    # Initialize API
    api = HfApi()
    
    # Directories to download
    # directories = ["0_9999/blurred", "0_9999/groundtruth"]
    directories = ["0_9999/groundtruth"]

    # Create local directories
    for directory in directories:
        full_path = os.path.join(output_dir, directory)
        os.makedirs(full_path, exist_ok=True)
    
    # Get all files in repository
    print("Fetching file list...")
    repo_files = api.list_repo_files(repo_id=repo_id, repo_type=repo_type)
    
    # Download files from each directory
    for directory in directories:
        print(f"\nDownloading files from {directory}...")
        
        # Get files in this directory
        directory_files = [f for f in repo_files if f.startswith(directory + "/")]
        print(f"Found {len(directory_files)} files in {directory}")
        
        # Download each file
        for i, file_path in enumerate(directory_files):
            print(f"Downloading {i+1}/{len(directory_files)}: {file_path}")
            try:
                hf_hub_download(
                    repo_id=repo_id,
                    filename=file_path,
                    repo_type=repo_type,
                    local_dir=output_dir,
                    local_dir_use_symlinks=False
                )
            except Exception as e:
                print(f"Error downloading {file_path}: {e}")
    
    print("\nDownload complete!")
    print(f"Files saved to: {output_dir}")

# Run the download
download_dataset()
# Out:
# Running cells with 'Restormer (Python 3.7.16)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n Restormer ipykernel --update-deps --force-reinstall'

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("masterda/SloMoBlur", split="train[10000]")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/shuogudaojin/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/shuogudaojin/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/shuogudaojin/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...

# %%
ds.save_to_disk("./Dataset/SloMoBlur")

# %%
#Todo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
### TODO
